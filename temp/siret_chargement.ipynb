# %%
# %reset -f out
# %run ../ipy
import pandas as pd
# Out:
# Flushing output cache (0 entries)

# %%
df = pd.read_csv('siret.csv', nrows=10000)

# %%
df.head(100).T
# Out:
#                                                                            0  \
# siren                                           325175
# nic                                             16
# siret                                           32517500016
# statutDiffusionEtablissement                    O
# dateCreationEtablissement                       2000-09-26
# trancheEffectifsEtablissement                   NaN
# anneeEffectifsEtablissement                     NaN
# activitePrincipaleRegistreMetiersEtablissement  3212ZZ
# dateDernierTraitementEtablissement              2015-03-18T00:58:59
# etablissementSiege                              False
# nombrePeriodesEtablissement                     3
# complementAdresseEtablissement                  NaN
# numeroVoieEtablissement                         NaN
# indiceRepetitionEtablissement                   NaN
# typeVoieEtablissement                           NaN
# ...

# %%
df2 = pd.read_csv('siret.csv', usecols=['siren', 'siret', 'denominationUsuelleEtablissement', 'activitePrincipaleEtablissement', 'libelleVoieEtablissement', 'numeroVoieEtablissement',
                                        'typeVoieEtablissement', 'codePostalEtablissement', 'libelleCommuneEtablissement',
                                        'codeCommuneEtablissement'])
df2.head()
# Out:
#     siren        siret numeroVoieEtablissement typeVoieEtablissement  \
# 0  325175  32517500016  NaN                     NaN
# 1  325175  32517500024  1                       PL
# 2  325175  32517500032  6                       AV
# 3  325175  32517500040  170                     AV
# 4  325175  32517500057  61                      RUE
#
#        libelleVoieEtablissement  codePostalEtablissement  \
# 0  MANIHI COTE MONTAGNE TUAMOTU  98770.0
# 1  LEONCE DE SEYNES              84140.0
# 2  FRANCOIS MAURIAC              84000.0
# 3  DU COL DE L ANGE              13420.0
# 4  MARX DORMOY                   13004.0
#
#   libelleCommuneEtablissement codeCommuneEtablissement  \
# 0  MANIHI                      98727
# 1  AVIGNON                     84007
# 2  AVIGNON                     84007
# 3  GEMENOS                     13042
# 4  MARSEILLE 4                 13204
#
#   denominationUsuelleEtablissement activitePrincipaleEtablissement
# 0  NaN                              32.12Z
# ...

# %%
df2.to_pickle('apres_chargement_1.pkl')

# %%
df = pd.read_pickle('apres_chargement_1.pkl')
df.head()
# Out:
#     siren        siret numeroVoieEtablissement typeVoieEtablissement  \
# 0  325175  32517500016  NaN                     NaN
# 1  325175  32517500024  1                       PL
# 2  325175  32517500032  6                       AV
# 3  325175  32517500040  170                     AV
# 4  325175  32517500057  61                      RUE
#
#        libelleVoieEtablissement  codePostalEtablissement  \
# 0  MANIHI COTE MONTAGNE TUAMOTU  98770.0
# 1  LEONCE DE SEYNES              84140.0
# 2  FRANCOIS MAURIAC              84000.0
# 3  DU COL DE L ANGE              13420.0
# 4  MARX DORMOY                   13004.0
#
#   libelleCommuneEtablissement codeCommuneEtablissement  \
# 0  MANIHI                      98727
# 1  AVIGNON                     84007
# 2  AVIGNON                     84007
# 3  GEMENOS                     13042
# 4  MARSEILLE 4                 13204
#
#   denominationUsuelleEtablissement activitePrincipaleEtablissement
# 0  NaN                              32.12Z
# ...

# %%
df = df[df.denominationUsuelleEtablissement.notna()]
df = df.copy()
df.head()
# Out:
#         siren         siret numeroVoieEtablissement typeVoieEtablissement  \
# 119   5450093  545009300033  NaN                     AV
# 120   5450093  545009300041  36                      RUE
# 573   5620117  562011700019  12                      RUE
# 4294  6480065  648006500025  5                       RUE
# 5388  6773386  677338600054  17                      RUE
#
#      libelleVoieEtablissement  codePostalEtablissement  \
# 119   DES THERMES              4800.0
# 120   GRANDE                   4800.0
# 573   DE LA TANNERIE           80100.0
# 4294  NICOLAS APPERT           44400.0
# 5388  GREBES                   44510.0
#
#      libelleCommuneEtablissement codeCommuneEtablissement  \
# 119   GREOUX-LES-BAINS            04094
# 120   GREOUX-LES-BAINS            04094
# 573   ABBEVILLE                   80001
# 4294  REZE                        44143
# 5388  LE POULIGUEN                44135
#
#      denominationUsuelleEtablissement activitePrincipaleEtablissement
# ...

# %%
len(df.loc[df.denominationUsuelleEtablissement.str.contains('MINISTERE')])
# Out:
# 6

# %%
df.loc[df.denominationUsuelleEtablissement.str.contains('MINISTERE')]
# Out:
#               siren           siret numeroVoieEtablissement  \
# 23499563  790524755  79052475500010  25
# 24087068  797511276  79751127600017  565
# 24786590  803657204  80365720400019  47
# 24786591  803657204  80365720400027  3
# 25844989  814750220  81475022000018  24
# 28376781  847550266  84755026600021  83
#
#          typeVoieEtablissement libelleVoieEtablissement  \
# 23499563  RUE                   DE PONTHIEU
# 24087068  AV                    DU PRADO
# 24786590  RUE                   JEAN SANS PEUR
# 24786591  RUE                   ETEX
# 25844989  NaN                   CLOS DES EGLANTINES
# 28376781  RUE                   DE L'UNIVERSITE
#
#           codePostalEtablissement libelleCommuneEtablissement  \
# 23499563  75008.0                  PARIS 8
# 24087068  13008.0                  MARSEILLE 8
# 24786590  59800.0                  LILLE
# 24786591  75018.0                  PARIS 18
# 25844989  78280.0                  GUYANCOURT
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29261864 entries, 0 to 29261863
# Data columns (total 10 columns):
# siren                               int64
# siret                               int64
# numeroVoieEtablissement             object
# typeVoieEtablissement               object
# libelleVoieEtablissement            object
# codePostalEtablissement             float64
# libelleCommuneEtablissement         object
# codeCommuneEtablissement            object
# denominationUsuelleEtablissement    object
# activitePrincipaleEtablissement     object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 2.2+ GB

# %%
df2.activitePrincipaleEtablissement.value_counts().sort_values(ascending=False)
# Out:
# 68.20B    2228284
# 68.20A    743404
# 94.99Z    599782
# 70.22Z    525821
# 70.2C     332607
# 86.90D    324344
# 86.90E    310545
# 70.10Z    291475
# 43.99C    284927
# 56.10A    272075
# 74.1J     261149
# 47.99A    255044
# 56.10C    254650
# 85.1G     241671
# 01.11Z    224466
# 64.20Z    221784
# 68.31Z    219404
# 69.10Z    218872
# 47.89Z    217571
# 86.21Z    203277
# 55.3A     194703
# 43.34Z    189943
# 96.09Z    189614
# 43.21A    187454
# 90.01Z    187220
# 96.02A    180946
# 93.12Z    180270
# 47.71Z    168779
# 71.12B    166694
# 46.19B    166140
# 81.10Z    161991
# 01.21Z    160537
# 90.03A    160325
# 49.32Z    159297
# 86.90F    158720
# 45.2V     156772
# 85.1C     155076
# 70.2A     144506
# 45.11Z    139209
# 62.01Z    137444
# 45.20A    137146
# 96.02B    136659
# 81.21Z    134156
# 85.51Z    132591
# 74.1G     132584
# 43.32A    132220
# 93.29Z    131445
# 85.59A    131125
# 01.1A     129627
# 62.02A    129439
# 52.6E     128558
# 53.20Z    120110
# ...

# %%
df3 = df2.loc[(df2.denominationUsuelleEtablissement.notna()) & (df2.activitePrincipaleEtablissement == '8411Z')]

# %%
df3.head()
# Out:
# Empty DataFrame
# Columns: [siren, siret, numeroVoieEtablissement, typeVoieEtablissement, libelleVoieEtablissement, codePostalEtablissement, libelleCommuneEtablissement, codeCommuneEtablissement, denominationUsuelleEtablissement, activitePrincipaleEtablissement]
# Index: []

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 10 columns):
# siren                               0 non-null int64
# siret                               0 non-null int64
# numeroVoieEtablissement             0 non-null object
# typeVoieEtablissement               0 non-null object
# libelleVoieEtablissement            0 non-null object
# codePostalEtablissement             0 non-null float64
# libelleCommuneEtablissement         0 non-null object
# codeCommuneEtablissement            0 non-null object
# denominationUsuelleEtablissement    0 non-null object
# activitePrincipaleEtablissement     0 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 0.0+ bytes
